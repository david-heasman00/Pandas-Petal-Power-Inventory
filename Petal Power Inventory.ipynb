# %% [markdown]
# *This fun, step by step, project "Petal Power Inventory" is part of Codecademy's chapter on Python Pandas for Data Science, part of Data Science Foundations II, which is overrall part of the career path [Data Scientist Machine Learning](https://www.codecademy.com/learn/paths/data-science).*
#
# *(It's a big course).*
#
# *While this could be done in the interactive Codecademy window, I decided to copy it here into Jupyter, just so there's actually a record that I did the dang thing.*
#
# *It consolidates and tests one's knowledge of creating, accessing, and modifying dataframes in Pandas.*
#
# *Enjoy.*

# %% [markdown]
# ## Petal Power Inventory
#
# You’re the lead data analyst for a chain of gardening stores called Petal Power. Help them analyze their inventory!

# %% [markdown]
# 1. Data for all of the locations of Petal Power is in the file `inventory.csv`. Load the data into a DataFrame called `inventory`.

# %%
import pandas as pd

#Read CSV into dataframe
inventory = pd.read_csv('inventory.csv')

# %% [markdown]
# 2. Inspect the first 10 rows of `inventory`.

# %%
#Inspect 1st 10 rows of inventory
inventory.head(10)
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %% [markdown]
# 3. The first 10 rows represent data from your Staten Island location. Select these rows and save them to `staten_island`.

# %%
#Slice first 10 rows of inventory into staten_island and inspect
staten_island = inventory[:10]
staten_island.head(11)
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %% [markdown]
# 4. A customer just emailed you asking what products are sold at your Staten Island location. Select the column `product_description` from `staten_island` and save it to the variable `product_request`.

# %%
#Select product_request and inspect
product_request = staten_island['product_description']
product_request.head(10)
# Out:
# 0                         daisy
# 1                    calla lily
# 2                        tomato
# 3                          rake
# 4                   wheelbarrow
# 5                         spade
# 6                 insect killer
# 7                   weed killer
# 8    20 inch terracotta planter
# 9        8 inch plastic planter
# Name: product_description, dtype: object

# %% [markdown]
# 5. Another customer emails to ask what types of seeds are sold at the Brooklyn location.
#
#     Select all rows where `location` is equal to Brooklyn and `product_type` is equal to `seeds` and save them to the variable `seed_request`.

# %%
#Select seeds in Brooklyn
seed_request = inventory[(inventory['location'] == 'Brooklyn') & (inventory['product_type'] == 'seeds')]
seed_request.head(10)
# Out:
#     location product_type product_description  quantity  price
# 10  Brooklyn        seeds               daisy        50   6.99
# 11  Brooklyn        seeds          calla lily         0  19.99
# 12  Brooklyn        seeds              tomato         0  13.99

# %% [markdown]
# ### Inventory
#
# 6. Add a column to `inventory` called `in_stock` which is `True` if `quantity` is greater than 0 and `False` if `quantity` equals 0.

# %%
#Create new "in_stock" column
inventory['in_stock'] = inventory['quantity'].apply(lambda x: True if x > 0 else False)
inventory.head(10)
# Out:
#         location  product_type         product_description  quantity  price  \
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99
#
#    in_stock
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# ...

# %% [markdown]
# 7. Petal Power wants to know how valuable their current inventory is.
#
#     Create a column called `total_value` that is equal to `price` multiplied by `quantity`.

# %%
#Create new 'total_value' column
inventory['total_value'] = inventory['price'] * inventory['quantity']
inventory.head(10)
# Out:
#         location  product_type         product_description  quantity  price  \
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99
#
#    in_stock  total_value
# 0      True        27.96
# 1      True       919.54
# 2      True      1189.15
# 3      True        55.96
# ...

# %% [markdown]
# 8.
# The Marketing department wants a complete description of each product for their catalog.
#
# The following lambda function combines `product_type` and `product_description` into a single string:
#
# ```Python
# combine_lambda = lambda row: \
#     '{} - {}'.format(row.product_type,
#                      row.product_description)
# ```
#
# Paste this function into `script.py`.

# %%
#Create product description function
combine_lambda = lambda row: \
    '{} - {}'.format(row.product_type,
                     row.product_description)

# %% [markdown]
# 9. Using `combine_lambda`, create a new column in `inventory` called `full_description` that has the complete description of each product.

# %%
#Create full_description column based on previous function
inventory['full_description'] = inventory.apply(combine_lambda, axis=1)
inventory.head(10)
# Out:
#         location  product_type         product_description  quantity  price  \
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99
#
#    in_stock  total_value                      full_description
# 0      True        27.96                         seeds - daisy
# ...
